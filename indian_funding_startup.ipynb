# %% [markdown]
# <a href="https://colab.research.google.com/github/Swapn2/Data-Science-Learnings/blob/main/indian_funding_startup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/startup_funding.csv')

# %%
df
# Out:
#       Sr No Date dd/mm/yyyy                  Startup Name  \
# 0         1      09/01/2020                        BYJU’S
# 1         2      13/01/2020                        Shuttl
# 2         3      09/01/2020                     Mamaearth
# 3         4      02/01/2020  https://www.wealthbucket.in/
# 4         5      02/01/2020                        Fashor
# ...     ...             ...                           ...
# 3039   3040      29/01/2015                    Printvenue
# 3040   3041      29/01/2015                      Graphene
# 3041   3042      30/01/2015                Mad Street Den
# 3042   3043      30/01/2015                     Simplotel
# 3043   3044      31/01/2015              couponmachine.in
#
#         Industry Vertical                            SubVertical  \
# 0                  E-Tech                             E-learning
# 1          Transportation              App based shuttle service
# 2              E-commerce  Retailer of baby and toddler products
# ...

# %%
start_up = sorted(df['Startup Name'].unique().tolist())

# %%
start_up
# Out:
# ['"BYJU\\\\\'S"',
#  '#Fame',
#  '121Policy',
#  '19th mile',
#  '1Crowd',
#  '1mg',
#  '1mg (Healthkartplus)',
#  '20Dresses',
#  '33Coupons',
#  '360Ride',
#  '3Dexter',
#  '3HCare',
#  '3rdFlix',
#  '48East',
#  '4tigo',
#  '5th Vital',
#  '6Degree',
#  '75F',
#  '91SpringBoard',
#  '99Games',
#  '99PerHour',
#  '9Stacks',
#  'A&R Bon Vivants',
#  'ABI Health',
#  'AEON Learning',
#  'AHA Taxis',
#  'AYE Finance',
#  'AadharAPI.com',
#  'Aadyah',
#  'Aahaa',
#  'Aahaa Stores',
#  'Aarav UAV',
#  'Aasaanjobs',
#  'Aashiyaan',
#  'Aavishkaar-Intellecap Group',
#  'AbeRuk',
#  'Abhibus',
#  'Absentia',
#  'Absentia VR',
#  'Ace Turtle',
#  'Ace2three',
#  'Acko',
#  'ActOnMagic',
#  'Actionable Analytics',
#  'Active AI',
#  'Active.ai',
#  'Actofit',
#  'Ad2pro',
#  'AdPushUp',
#  'AdStringO',
#  'AdUrCup',
#  'AdWyze',
#  'Address Health',
#  'AdmitKard',
#  'Advanced Structures India',
#  'Advantage Club',
#  'Advenio',
#  'Adytude',
#  'Aequm',
#  'AerMed',
#  'Affimity',
# ...

# %%
df.head(4)
# Out:
#    Sr No Date dd/mm/yyyy                  Startup Name Industry Vertical  \
# 0      1      09/01/2020                        BYJU’S            E-Tech
# 1      2      13/01/2020                        Shuttl    Transportation
# 2      3      09/01/2020                     Mamaearth        E-commerce
# 3      4      02/01/2020  https://www.wealthbucket.in/           FinTech
#
#                              SubVertical City  Location  \
# 0                             E-learning      Bengaluru
# 1              App based shuttle service        Gurgaon
# 2  Retailer of baby and toddler products      Bengaluru
# 3                      Online Investment      New Delhi
#
#               Investors Name       InvestmentnType Amount in USD Remarks
# 0    Tiger Global Management  Private Equity Round  20,00,00,000     NaN
# 1  Susquehanna Growth Equity              Series C     80,48,394     NaN
# 2      Sequoia Capital India              Series B   1,83,58,860     NaN
# ...

# %%
df['Investors Name'] = df['Investors Name'].fillna('undisclosed')

# %%
investor = sorted(df['Investors Name'].unique().tolist())

# %%
investor
# Out:
# ['"Kedaraa Capital, Ontario Teachers\\\\\'"',
#  '021 Capita, Binny Bansal',
#  '1Crowd',
#  '1Crowd (through crowd funding)',
#  '1Crowd (through crowdfunding)',
#  '1Crowd, Ankur Capital',
#  '1Crowd, Eureka Forbes Ltd, Shapoorji Pallonji & Co. Ltd.',
#  '3 undisclosed HNIs',
#  '3 undisclosed investors',
#  '3One4 Capital',
#  '3one4 Capital, Mumbai Angels, Aarin Capital',
#  '3one4 Capital, Tracxn Labs, Aaruha Technology Fund, Endiya Partners',
#  '3one4 capital',
#  '500 Startups',
#  '500 Startups, IDG Ventures & Advantedge fund, Neeraj Arora, Leon Seynave',
#  '500 Startups, IvyCap Ventures',
#  '500 Startups, Littlerock, Singularity Ventures',
#  '500 Startups, Mato Peric & Others',
#  '500 Startups, Mato Peric, TracxnLabs',
#  '500 Startups, Purvi Capital, Rajan Anandan, Abhishek Gupta',
#  '500 Startups, Smile Multimedia, Kunal Bahl, Rohit Bansal, Girish Matrubootham',
#  '500 Startups, TV Mohandas Pai, Tandem Capital, Vikram Chachra, Aloke Bajpai',
#  '50K Ventures',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3044 entries, 0 to 3043
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Sr No              3044 non-null   int64
#  1   Date dd/mm/yyyy    3044 non-null   object
#  2   Startup Name       3044 non-null   object
#  3   Industry Vertical  2873 non-null   object
#  4   SubVertical        2108 non-null   object
#  5   City  Location     2864 non-null   object
#  6   Investors Name     3044 non-null   object
#  7   InvestmentnType    3040 non-null   object
#  8   Amount in USD      2084 non-null   object
#  9   Remarks            419 non-null    object
# dtypes: int64(1), object(9)
# memory usage: 237.9+ KB

# %%
df.head(5)
# Out:
#    Sr No Date dd/mm/yyyy                  Startup Name    Industry Vertical  \
# 0      1      09/01/2020                        BYJU’S               E-Tech
# 1      2      13/01/2020                        Shuttl       Transportation
# 2      3      09/01/2020                     Mamaearth           E-commerce
# 3      4      02/01/2020  https://www.wealthbucket.in/              FinTech
# 4      5      02/01/2020                        Fashor  Fashion and Apparel
#
#                              SubVertical City  Location  \
# 0                             E-learning      Bengaluru
# 1              App based shuttle service        Gurgaon
# 2  Retailer of baby and toddler products      Bengaluru
# 3                      Online Investment      New Delhi
# 4            Embroiled Clothes For Women         Mumbai
#
#               Investors Name       InvestmentnType Amount in USD Remarks
# 0    Tiger Global Management  Private Equity Round  20,00,00,000     NaN
# ...

# %%
df.drop(columns=['Remarks'],inplace=True)

# %%
df.set_index('Sr No',inplace = True)

# %%
df.rename(columns={
    'Date dd/mm/yyyy':'date',
    'Startup Name':'startup',
    'Industry Vertical':'vertical',
    'SubVertical':'subvertical',
    'City  Location':'city',
    'Investors Name':'investors',
    'InvestmentnType':'round',
    'Amount in USD':'amount'

},inplace=True)

# %%
df.columns
# Out:
# Index(['date', 'startup', 'vertical', 'subvertical', 'city', 'investors',
#        'round', 'amount'],
#       dtype='object')

# %%
df['amount'] = df['amount'].fillna('0')

df['amount'] = df['amount'].str.replace('undisclosed','0')
df['amount'] = df['amount'].str.replace(',','')
df['amount'] = df['amount'].str.replace('Undisclosed','0')
df['amount'] = df['amount'].str.replace('Unknown','0')
df = df[df['amount'].str.isdigit()]

# %%
df['amount']=df['amount'].astype('float')
# Out:
# <ipython-input-278-01920b0833e7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['amount']=df['amount'].astype('float')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3028 entries, 1 to 3044
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         3028 non-null   object
#  1   startup      3028 non-null   object
#  2   vertical     2857 non-null   object
#  3   subvertical  2103 non-null   object
#  4   city         2848 non-null   object
#  5   investors    3028 non-null   object
#  6   round        3026 non-null   object
#  7   amount       3028 non-null   float64
# dtypes: float64(1), object(7)
# memory usage: 212.9+ KB

# %%
df.head(3)
# Out:
#              date    startup        vertical  \
# Sr No
# 1      09/01/2020     BYJU’S          E-Tech
# 2      13/01/2020     Shuttl  Transportation
# 3      09/01/2020  Mamaearth      E-commerce
#
#                                  subvertical       city  \
# Sr No
# 1                                 E-learning  Bengaluru
# 2                  App based shuttle service    Gurgaon
# 3      Retailer of baby and toddler products  Bengaluru
#
#                        investors                 round       amount
# Sr No
# 1        Tiger Global Management  Private Equity Round  200000000.0
# 2      Susquehanna Growth Equity              Series C    8048394.0
# 3          Sequoia Capital India              Series B   18358860.0

# %%
def to_inr(dollar):
  inr = dollar*82.30
  return inr/10000000

# %%
df['amount'] = df['amount'].apply(to_inr)
# Out:
# <ipython-input-282-4a4043d0e093>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['amount'] = df['amount'].apply(to_inr)

# %%
df['amount']
# Out:
# Sr No
# 1       1646.000000
# 2         66.238283
# 3        151.093418
# 4         24.690000
# 5         14.814000
#            ...
# 3040      37.035000
# 3041       6.789750
# 3042      12.345000
# 3043       0.000000
# 3044       1.152200
# Name: amount, Length: 3028, dtype: float64

# %%
df['date'] = pd.to_datetime(df['date'], format='%d/%m/%Y', errors='coerce')
# Out:
# <ipython-input-284-c2a552afb959>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['date'] = pd.to_datetime(df['date'], format='%d/%m/%Y', errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3028 entries, 1 to 3044
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         3021 non-null   datetime64[ns]
#  1   startup      3028 non-null   object
#  2   vertical     2857 non-null   object
#  3   subvertical  2103 non-null   object
#  4   city         2848 non-null   object
#  5   investors    3028 non-null   object
#  6   round        3026 non-null   object
#  7   amount       3028 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(6)
# memory usage: 212.9+ KB

# %%
df['date']
# Out:
# Sr No
# 1      2020-01-09
# 2      2020-01-13
# 3      2020-01-09
# 4      2020-01-02
# 5      2020-01-02
#           ...
# 3040   2015-01-29
# 3041   2015-01-29
# 3042   2015-01-30
# 3043   2015-01-30
# 3044   2015-01-31
# Name: date, Length: 3028, dtype: datetime64[ns]

# %%
df['date'].dt.month
# Out:
# Sr No
# 1       1.0
# 2       1.0
# 3       1.0
# 4       1.0
# 5       1.0
#        ...
# 3040    1.0
# 3041    1.0
# 3042    1.0
# 3043    1.0
# 3044    1.0
# Name: date, Length: 3028, dtype: float64

# %%
df = df.dropna(subset = ['date','startup','city','investors','round','amount','vertical'])

# %%
df.to_csv('starup_clean.csv',index=False)

# %%
sorted(set(df['investors'].str.split(',').sum()))
# Out:
# ['',
#  ' & Others',
#  ' 100 Co-founders Lab and others.',
#  ' 122 West Ventures',
#  ' 1Crowd',
#  ' 3ONE4 Capital Advisors',
#  ' 3one4 Capital',
#  ' 3one4 Capital Advisors LLP',
#  ' 500 Start-Ups',
#  ' 500 Startups',
#  ' 500 Startups & Other HNIs',
#  ' 50K Ventures & others',
#  ' 91SpringBoard',
#  ' 91springboard',
#  ' ABB Technology Ventures',
#  ' ABCOM Investments',
#  ' AECAL',
#  ' AET Fund',
#  ' AL Nour International Holdings and Mark V Investments',
#  ' ASP Consulting',
#  ' AVN Business Solutions',
#  ' Aarin Capital',
#  ' Aarin Capital & Others',
#  ' Aaruha Technology Fund',
#  ' Abaran Deep',
#  ' Abhai S. Rao',
#  ' Abhay Singhal',
#  ' Abhijit Bhandari',
#  ' Abhinav Patodia',
#  ' Abhinav Sinha',
#  ' Abhishek Acharya',
#  ' Abhishek Goyal',
#  ' Abhishek Gupta',
#  ' Abhishek Jain',
#  ' Abhishekh Goyal',
#  ' Abstract Ventures',
#  ' Abu Farhan Azmi',
#  ' Accel',
#  ' Accel India',
#  ' Accel Partner',
#  ' Accel Partners',
# ...

# %%
df[df['investors'].str.contains('Sequoia Capital')][['date','startup','vertical','city','amount']]
# Out:
#             date               startup                           vertical  \
# Sr No
# 3     2020-01-09             Mamaearth                         E-commerce
# 69    2019-07-11                Moglix                         E-Commerce
# 93    2019-05-01             BlackBuck                          Transport
# 114   2019-02-08               Zilingo                          Ecommerce
# 150   2018-10-12             Blackbuck                     Logistics Tech
# ...          ...                   ...                                ...
# 2825  2015-04-09          Urban Ladder      Online Furnishing\\neCommerce
# 2836  2015-04-15               Grofers  Hyper-Local Online/Mobile Grocery
# 2837  2015-04-15             PepperTap  Hyper-Local Online/Mobile Grocery
# 2845  2015-04-20  1mg (Healthkartplus)          Online Pharmacy & Drug DB
# 2852  2015-04-23          Craftstvilla           Ethnic Product eCommerce
#
#                   city       amount
# Sr No
# ...

# %%
df[df['investors'].str.contains('Sequoia Capital')].groupby('startup')['amount'].sum().sort_values(ascending = False)
# Out:
# startup
# Oyo Rooms       2880.500
# OYO Rooms       2057.500
# Zilingo         1859.980
# Grofers         1275.650
# BlackBuck       1234.500
#                   ...
# Increff           16.460
# Goodservice       13.168
# CleverTap          0.000
# HelpChat           0.000
# PressPlay TV       0.000
# Name: amount, Length: 69, dtype: float64

# %%
df[df['investors'].str.contains('Sequoia Capital')].groupby('vertical')['amount'].sum().plot(kind='pie')
# Out:
# <Axes: ylabel='amount'>

# %%
df[df['investors'].str.contains('Sequoia Capital')].groupby('round')['amount'].sum().plot(kind='pie')
# Out:
# <Axes: ylabel='amount'>

# %%
df[df['investors'].str.contains('Sequoia Capital')].groupby('city')['amount'].sum().plot(kind='pie')
# Out:
# <Axes: ylabel='amount'>

# %%
df['year'] = df['date'].dt.year

# %%
df
# Out:
#             date                       startup                    vertical  \
# Sr No
# 1     2020-01-09                        BYJU’S                      E-Tech
# 2     2020-01-13                        Shuttl              Transportation
# 3     2020-01-09                     Mamaearth                  E-commerce
# 4     2020-01-02  https://www.wealthbucket.in/                     FinTech
# 5     2020-01-02                        Fashor         Fashion and Apparel
# ...          ...                           ...                         ...
# 2869  2015-04-29                        Tracxn  Startup Analytics platform
# 2870  2015-04-29                          Dazo    Mobile Food Ordering app
# 2871  2015-04-29                      Tradelab  Financial Markets Software
# 2872  2015-04-29                        PiQube   Hiring Analytics platform
# 2873  2015-04-29               Travel Triangle   Online Travel Marketplace
#
#                                  subvertical       city  \
# ...

# %%
df[df['investors'].str.contains('Sequoia Capital')].groupby('year')['amount'].sum()
# .plot()
# Out:
# year
# 2015    7946.065000
# 2016    2841.407500
# 2017    5497.640000
# 2018    1582.711300
# 2019    3588.280000
# 2020     151.093418
# Name: amount, dtype: float64

# %%
df.head(3)
# Out:
#             date    startup        vertical  \
# Sr No
# 1     2020-01-09     BYJU’S          E-Tech
# 2     2020-01-13     Shuttl  Transportation
# 3     2020-01-09  Mamaearth      E-commerce
#
#                                  subvertical       city  \
# Sr No
# 1                                 E-learning  Bengaluru
# 2                  App based shuttle service    Gurgaon
# 3      Retailer of baby and toddler products  Bengaluru
#
#                        investors                 round       amount  year
# Sr No
# 1        Tiger Global Management  Private Equity Round  1646.000000  2020
# 2      Susquehanna Growth Equity              Series C    66.238283  2020
# 3          Sequoia Capital India              Series B   151.093418  2020

# %%
df['amount'].sum()
# Out:
# np.float64(300837.40764978004)

# %%
int(df.groupby('startup')['amount'].sum().sort_values(ascending=False).head(1).values[0])
# Out:
# 33411

# %%
int(df.groupby('startup')['amount'].sum().mean())
# Out:
# 129

# %%
int(df['startup'].nunique())
# Out:
# 2315

# %%
df['month'] = df['date'].dt.month

# %%
df.head()
# Out:
#             date                       startup             vertical  \
# Sr No
# 1     2020-01-09                        BYJU’S               E-Tech
# 2     2020-01-13                        Shuttl       Transportation
# 3     2020-01-09                     Mamaearth           E-commerce
# 4     2020-01-02  https://www.wealthbucket.in/              FinTech
# 5     2020-01-02                        Fashor  Fashion and Apparel
#
#                                  subvertical       city  \
# Sr No
# 1                                 E-learning  Bengaluru
# 2                  App based shuttle service    Gurgaon
# 3      Retailer of baby and toddler products  Bengaluru
# 4                          Online Investment  New Delhi
# 5                Embroiled Clothes For Women     Mumbai
#
#                        investors                 round       amount  year  \
# Sr No
# 1        Tiger Global Management  Private Equity Round  1646.000000  2020
# ...

# %%
df.groupby(['year','month'])['startup'].count().reset_index()
# Out:
#     year  month  startup
# 0   2015      4       62
# 1   2015      5       55
# 2   2015      6       85
# 3   2015      7       85
# 4   2015      8       98
# 5   2015      9       88
# 6   2015     10       93
# 7   2015     11       92
# 8   2015     12       89
# 9   2016      1      104
# 10  2016      2       99
# 11  2016      3       84
# 12  2016      4       77
# 13  2016      5       79
# 14  2016      6       97
# 15  2016      7       63
# 16  2016      8       87
# 17  2016      9       73
# 18  2016     10       80
# 19  2016     11       72
# 20  2016     12       72
# 21  2017      1       72
# 22  2017      2       48
# 23  2017      3       71
# 24  2017      4       71
# 25  2017      5       68
# 26  2017      6       65
# 27  2017      7       43
# 28  2017      8       45
# 29  2017      9       58
# 30  2017     10       53
# 31  2017     11       50
# 32  2017     12       43
# 33  2018      1       37
# 34  2018      2       42
# 35  2018      3       34
# ...

# %%
temp_df = df.groupby(['year','month'])['amount'].sum().reset_index()
temp_df['x_axis'] = temp_df['year'].astype(str) + '-' + temp_df['month'].astype(str)

# %%
temp_df[['amount','x_axis']]
# Out:
#           amount   x_axis
# 0    8069.515000   2015-4
# 1    2634.711050   2015-5
# 2    4296.010620   2015-6
# 3   12420.650160   2015-7
# 4    8755.205680   2015-8
# 5   12102.379600   2015-9
# 6    2098.329030  2015-10
# 7    7401.033250  2015-11
# 8    2517.170190  2015-12
# 9    5760.012400   2016-1
# 10   2728.166815   2016-2
# 11   2547.692034   2016-3
# 12   2089.926200   2016-4
# 13   2796.883200   2016-5
# 14   1643.028970   2016-6
# 15   1922.091810   2016-7
# 16   4395.552470   2016-8
# 17   1986.401030   2016-9
# 18   1954.197040  2016-10
# 19   2139.775310  2016-11
# 20   1541.009890  2016-12
# 21   2084.111705   2017-1
# 22   2427.512570   2017-2
# 23  18635.032630   2017-3
# 24   6027.610850   2017-4
# 25  14704.285870   2017-5
# 26   2837.852140   2017-6
# 27   1380.203920   2017-7
# 28  22617.183970   2017-8
# 29   4415.411460   2017-9
# 30   3295.185010  2017-10
# 31   5068.052353  2017-11
# 32   2340.776600  2017-12
# 33   2858.892958   2018-1
# ...

# %%
temp_df = df.groupby(['year','month'])['amount'].count().reset_index()
temp_df['x_axis'] = temp_df['year'].astype(str) + '-' + temp_df['month'].astype(str)

# %%
temp_df
# Out:
#     year  month  amount   x_axis
# 0   2015      4      62   2015-4
# 1   2015      5      55   2015-5
# 2   2015      6      85   2015-6
# 3   2015      7      85   2015-7
# 4   2015      8      98   2015-8
# 5   2015      9      88   2015-9
# 6   2015     10      93  2015-10
# 7   2015     11      92  2015-11
# 8   2015     12      89  2015-12
# 9   2016      1     104   2016-1
# 10  2016      2      99   2016-2
# 11  2016      3      84   2016-3
# 12  2016      4      77   2016-4
# 13  2016      5      79   2016-5
# 14  2016      6      97   2016-6
# 15  2016      7      63   2016-7
# 16  2016      8      87   2016-8
# 17  2016      9      73   2016-9
# 18  2016     10      80  2016-10
# 19  2016     11      72  2016-11
# 20  2016     12      72  2016-12
# 21  2017      1      72   2017-1
# 22  2017      2      48   2017-2
# 23  2017      3      71   2017-3
# 24  2017      4      71   2017-4
# 25  2017      5      68   2017-5
# 26  2017      6      65   2017-6
# ...
