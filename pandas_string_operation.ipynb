# %% [markdown]
# <a href="https://colab.research.google.com/github/Swapn2/Data-Science-Learnings/blob/main/pandas_string_operation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
# what are vectorized operation
a = np.array([1,2,3,4])

# %%
a
# Out:
# array([1, 2, 3, 4])

# %%
# problem in the vectorized operation in vanilla python
s = ['cat','mat',None,'rat']
[i.startswith('c') for i in s]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-66-193cd38f9f4d> in <cell line: 0>()
#       1 # problem in the vectorized operation in vanilla python
#       2 s = ['cat','mat',None,'rat']
# ----> 3 [i.startswith('c') for i in s]
#
# <ipython-input-66-193cd38f9f4d> in <listcomp>(.0)
#       1 # problem in the vectorized operation in vanilla python
#       2 s = ['cat','mat',None,'rat']
# ----> 3 [i.startswith('c') for i in s]
#
# AttributeError: 'NoneType' object has no attribute 'startswith'

# %%
# how pandas solve this issue
s = pd.Series(['cat','mat',None,'rat'])
# string acessor
s.str.startswith('c')
# Out:
# 0     True
# 1    False
# 2     None
# 3    False
# dtype: object

# %%
df = pd.read_csv('/content/titanic.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
# lower/upper/capitalize/title
df['Name'].str.lower()
df['Name'].str.capitalize()
df['Name'].str.title()
df['Name'].str.len()
# Out:
# 0      23
# 1      51
# 2      22
# 3      44
# 4      24
#        ..
# 886    21
# 887    28
# 888    40
# 889    21
# 890    19
# Name: Name, Length: 891, dtype: int64

# %%
df['Name'][df['Name'].str.len() == 82].values[0]
# Out:
# 'Penasco y Castellana, Mrs. Victor de Satode (Maria Josefa Perez de Soto y Vallejo)'

# %%
"       swapn      ".strip()
# Out:
# 'swapn'

# %%
df['Name'].str.strip()
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
df['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
df['Name'].str.split(',')
# Out:
# 0                             [Braund,  Mr. Owen Harris]
# 1      [Cumings,  Mrs. John Bradley (Florence Briggs ...
# 2                              [Heikkinen,  Miss. Laina]
# 3        [Futrelle,  Mrs. Jacques Heath (Lily May Peel)]
# 4                            [Allen,  Mr. William Henry]
#                              ...
# 886                             [Montvila,  Rev. Juozas]
# 887                      [Graham,  Miss. Margaret Edith]
# 888          [Johnston,  Miss. Catherine Helen "Carrie"]
# 889                             [Behr,  Mr. Karl Howell]
# 890                               [Dooley,  Mr. Patrick]
# Name: Name, Length: 891, dtype: object

# %%
df['lastname']=df['Name'].str.split(',').str.get(0)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['title'] = df['Name'].str.split(',').str.get(1).str.split('.').str.get(0)

# %%
df['firstname'] = df['Name'].str.split(',').str.get(1).str.split('.').str.get(1)
df['firstname']= df['firstname'].str.strip()

# %%
df[['title','firstname']]
# Out:
#      title                              firstname
# 0       Mr                            Owen Harris
# 1      Mrs  John Bradley (Florence Briggs Thayer)
# 2     Miss                                  Laina
# 3      Mrs          Jacques Heath (Lily May Peel)
# 4       Mr                          William Henry
# ..     ...                                    ...
# 886    Rev                                 Juozas
# 887   Miss                         Margaret Edith
# 888   Miss               Catherine Helen "Carrie"
# 889     Mr                            Karl Howell
# 890     Mr                                Patrick
#
# [891 rows x 2 columns]

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['title'].value_counts()
# Out:
# title
# Mr              517
# Miss            185
# Mrs             125
# Master           40
# Dr                7
# Rev               6
# Major             2
# Col               2
# Don               1
# Lady              1
# Mme               1
# Sir               1
# Capt              1
# the Countess      1
# Jonkheer          1
# Name: count, dtype: int64

# %%
df['title'] = df['title'].str.replace('Ms','Miss')
df['title'] = df['title'].str.replace('Mlle','Miss')

# %%
df['title'].value_counts()
# Out:
# title
# Mr              517
# Miss            185
# Mrs             125
# Master           40
# Dr                7
# Rev               6
# Major             2
# Col               2
# Don               1
# Lady              1
# Mme               1
# Sir               1
# Capt              1
# the Countess      1
# Jonkheer          1
# Name: count, dtype: int64

# %%
# startswith / endswith
df['firstname'][df['firstname'].str.startswith('A')]
# Out:
# 13            Anders Johan
# 22            Anna "Annie"
# 35         Alexander Oskar
# 38           Augusta Maria
# 61                  Amelie
#               ...
# 842                Augusta
# 845                Anthony
# 866               Asuncion
# 875    Adele Kiamie "Jane"
# 876          Alfred Ossian
# Name: firstname, Length: 95, dtype: object

# %%
df['firstname'][df['firstname'].str.contains('john',case = False)]
# Out:
# 1            John Bradley (Florence Briggs Thayer)
# 41     William John Robert (Dorothy Ann Wonnacott)
# 45                                    William John
# 98                         John T (Ada Julia Bone)
# 112                                     David John
# 117                            William John Robert
# 160                                  John Hatfield
# 162                                    John Viktor
# 165                   Frank John William "Frankie"
# 168                                         John D
# 188                                           John
# 212                                     John Henry
# 226                                   William John
# 227                            John Hall ("Henry")
# 324                                 George John Jr
# 328                 Frank John (Emily Alice Brown)
# 401                                           John
# 418                                   William John
# ...

# %%
# find lastname with start and end char vowel
# applying regx
df['lastname'][df['lastname'].str.contains('^[aeiouAEIOU].+[aeiouAEIOU]$')]
# Out:
# 30          Uruchurtu
# 49     Arnold-Franchi
# 207          Albimona
# 210               Ali
# 353    Arnold-Franchi
# 493      Artagaveytia
# 518             Angle
# 784               Ali
# 840          Alhomaki
# Name: lastname, dtype: object

# %%
# slicing
df['Name'].str[:4]
# Out:
# 0      Brau
# 1      Cumi
# 2      Heik
# 3      Futr
# 4      Alle
#        ...
# 886    Mont
# 887    Grah
# 888    John
# 889    Behr
# 890    Dool
# Name: Name, Length: 891, dtype: object
