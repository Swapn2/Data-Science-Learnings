# %% [markdown]
# <a href="https://colab.research.google.com/github/Swapn2/Data-Science-Learnings/blob/main/Decision_Tree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier , plot_tree
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
import numpy as np
from sklearn.tree import export_text

# %%
iris =  load_iris()
x = iris.data[:,:2]
y = iris.target

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = .2 , random_state = 42)

# %%
clf = DecisionTreeClassifier()
clf.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = clf.predict(x_test)
print(f"accuracy : {accuracy_score(y_test,y_pred)}")
# Out:
# accuracy : 0.6333333333333333

# %%
plt.figure(figsize=(12,8))
plot_tree(clf,filled= True,feature_names=iris.feature_names[:2],class_names=iris.target_names)
plt.show()

# %%
plt.figure(figsize=(10,6))
a = np.arange(x[:,0].min(-1) , x[:,0].max()+1, .01)
b = np.arange(x[:,1].min(-1) , x[:,1].max()+1, .01)
xx,yy = np.meshgrid(a,b)

# %%
z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
z = z.reshape(xx.shape)

# %%
plt.contour(xx,yy,z,alpha = .8)
plt.scatter(x[:,0], x[:,1],c= y , edgecolor = 'k')
plt.xlabel('sepal length')
plt.ylabel('sepal width')
# Out:
# Text(0, 0.5, 'sepal width')

# %%
r = export_text(clf,feature_names = iris.feature_names[:2])

# %%
print(r)
# Out:
# |--- sepal length (cm) <= 5.45
# |   |--- sepal width (cm) <= 2.80
# |   |   |--- sepal length (cm) <= 4.70
# |   |   |   |--- class: 0
# |   |   |--- sepal length (cm) >  4.70
# |   |   |   |--- sepal length (cm) <= 4.95
# |   |   |   |   |--- sepal width (cm) <= 2.45
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- sepal width (cm) >  2.45
# |   |   |   |   |   |--- class: 2
# |   |   |   |--- sepal length (cm) >  4.95
# |   |   |   |   |--- class: 1
# |   |--- sepal width (cm) >  2.80
# |   |   |--- sepal length (cm) <= 5.35
# |   |   |   |--- class: 0
# |   |   |--- sepal length (cm) >  5.35
# |   |   |   |--- sepal width (cm) <= 3.20
# |   |   |   |   |--- class: 1
# |   |   |   |--- sepal width (cm) >  3.20
# |   |   |   |   |--- class: 0
# |--- sepal length (cm) >  5.45
# |   |--- sepal length (cm) <= 6.15
# |   |   |--- sepal width (cm) <= 3.70
# |   |   |   |--- sepal length (cm) <= 5.75
# |   |   |   |   |--- sepal length (cm) <= 5.55
# ...
