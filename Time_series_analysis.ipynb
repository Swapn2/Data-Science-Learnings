# %% [markdown]
# <a href="https://colab.research.google.com/github/Swapn2/Data-Science-Learnings/blob/main/Time_series_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## timedelta object

# %%
t1 = pd.Timestamp('14th may 2025')
t2 = pd.Timestamp('31 july 2025')

t2 - t1
# Out:
# Timedelta('78 days 00:00:00')

# %%
pd.Timedelta(days=2, hours = 10)
# Out:
# Timedelta('2 days 10:00:00')

# %%
pd.date_range(start = '2025/05/14',end = '2025/07/31',freq = "D") + pd.Timedelta(days = 2 )
# Out:
# DatetimeIndex(['2025-05-16', '2025-05-17', '2025-05-18', '2025-05-19',
#                '2025-05-20', '2025-05-21', '2025-05-22', '2025-05-23',
#                '2025-05-24', '2025-05-25', '2025-05-26', '2025-05-27',
#                '2025-05-28', '2025-05-29', '2025-05-30', '2025-05-31',
#                '2025-06-01', '2025-06-02', '2025-06-03', '2025-06-04',
#                '2025-06-05', '2025-06-06', '2025-06-07', '2025-06-08',
#                '2025-06-09', '2025-06-10', '2025-06-11', '2025-06-12',
#                '2025-06-13', '2025-06-14', '2025-06-15', '2025-06-16',
#                '2025-06-17', '2025-06-18', '2025-06-19', '2025-06-20',
#                '2025-06-21', '2025-06-22', '2025-06-23', '2025-06-24',
#                '2025-06-25', '2025-06-26', '2025-06-27', '2025-06-28',
#                '2025-06-29', '2025-06-30', '2025-07-01', '2025-07-02',
#                '2025-07-03', '2025-07-04', '2025-07-05', '2025-07-06',
# ...

# %%
df = pd.read_csv('/content/deliveries.csv')

# %%
df.head()
# Out:
#   order_date delivery_date
# 0    5/24/98        2/5/99
# 1    4/22/92        3/6/98
# 2    2/10/91       8/26/92
# 3    7/21/92      11/20/97
# 4     9/2/93       6/10/98

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 501 entries, 0 to 500
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_date     501 non-null    object
#  1   delivery_date  501 non-null    object
# dtypes: object(2)
# memory usage: 8.0+ KB

# %%
df['order_date'] = pd.to_datetime(df['order_date'])
df['delivery_date'] = pd.to_datetime(df['delivery_date'])
# Out:
# <ipython-input-12-481df77f7c5d>:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['order_date'] = pd.to_datetime(df['order_date'])
# <ipython-input-12-481df77f7c5d>:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['delivery_date'] = pd.to_datetime(df['delivery_date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 501 entries, 0 to 500
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_date     501 non-null    datetime64[ns]
#  1   delivery_date  501 non-null    datetime64[ns]
# dtypes: datetime64[ns](2)
# memory usage: 8.0 KB

# %%
df['days'] = df['delivery_date'] - df['order_date']

# %%
df['days'].mean()
# Out:
# Timedelta('1217 days 22:53:53.532934128')

# %%
google = pd.read_csv('/content/google.csv')
google.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close    Volume
# 0  2004-08-19  49.813290  51.835709  47.800831  49.982655  49.982655  44871361
# 1  2004-08-20  50.316402  54.336334  50.062355  53.952770  53.952770  22942874
# 2  2004-08-23  55.168217  56.528118  54.321388  54.495735  54.495735  18342897
# 3  2004-08-24  55.412300  55.591629  51.591621  52.239197  52.239197  15319808
# 4  2004-08-25  52.284027  53.798351  51.746044  52.802086  52.802086   9232276

# %%
google.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4471 entries, 0 to 4470
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       4471 non-null   object
#  1   Open       4471 non-null   float64
#  2   High       4471 non-null   float64
#  3   Low        4471 non-null   float64
#  4   Close      4471 non-null   float64
#  5   Adj Close  4471 non-null   float64
#  6   Volume     4471 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 244.6+ KB

# %%
google['Date']= pd.to_datetime(google['Date'])

# %%
google.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4471 entries, 0 to 4470
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       4471 non-null   datetime64[ns]
#  1   Open       4471 non-null   float64
#  2   High       4471 non-null   float64
#  3   Low        4471 non-null   float64
#  4   Close      4471 non-null   float64
#  5   Adj Close  4471 non-null   float64
#  6   Volume     4471 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 244.6 KB

# %%
google.set_index('Date',inplace = True)

# %%
google
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2004-08-19    49.813290    51.835709    47.800831    49.982655    49.982655
# 2004-08-20    50.316402    54.336334    50.062355    53.952770    53.952770
# 2004-08-23    55.168217    56.528118    54.321388    54.495735    54.495735
# 2004-08-24    55.412300    55.591629    51.591621    52.239197    52.239197
# 2004-08-25    52.284027    53.798351    51.746044    52.802086    52.802086
# ...                 ...          ...          ...          ...          ...
# 2022-05-16  2307.679932  2332.149902  2286.699951  2295.850098  2295.850098
# 2022-05-17  2344.550049  2344.550049  2306.750000  2334.030029  2334.030029
# 2022-05-18  2304.750000  2313.913086  2242.840088  2248.020020  2248.020020
# 2022-05-19  2236.820068  2271.750000  2209.360107  2214.909912  2214.909912
# 2022-05-20  2241.709961  2251.000000  2127.459961  2186.260010  2186.260010
#
#               Volume
# Date
# ...

# %%
# fetch a specific date
google.loc['2021-5-14']
# Out:
# Open         2.291830e+03
# High         2.321140e+03
# Low          2.283320e+03
# Close        2.316160e+03
# Adj Close    2.316160e+03
# Volume       1.331200e+06
# Name: 2021-05-14 00:00:00, dtype: float64

# %%
google.loc['2021-12']
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2021-12-01  2884.250000  2929.982910  2830.000000  2832.360107  2832.360107
# 2021-12-02  2836.479980  2893.500000  2819.639893  2875.530029  2875.530029
# 2021-12-03  2889.909912  2904.260010  2823.000000  2850.409912  2850.409912
# 2021-12-06  2871.479980  2887.030029  2812.939941  2875.929932  2875.929932
# 2021-12-07  2919.000000  2966.000000  2914.050049  2960.729980  2960.729980
# 2021-12-08  2966.629883  2983.129883  2944.000000  2974.409912  2974.409912
# 2021-12-09  2963.520020  2992.100098  2950.580078  2962.120117  2962.120117
# 2021-12-10  2982.000000  2988.000000  2947.149902  2973.500000  2973.500000
# 2021-12-13  2968.879883  2971.250000  2927.199951  2934.090088  2934.090088
# 2021-12-14  2895.399902  2908.840088  2844.850098  2899.409912  2899.409912
# 2021-12-15  2887.320068  2950.344971  2854.110107  2947.370117  2947.370117
# ...

# %%
google['month'] = google.index.month_name()

# %%
google['day'] = google.index.day_name()

# %%
google.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume  \
# Date
# 2004-08-19  49.813290  51.835709  47.800831  49.982655  49.982655  44871361
# 2004-08-20  50.316402  54.336334  50.062355  53.952770  53.952770  22942874
# 2004-08-23  55.168217  56.528118  54.321388  54.495735  54.495735  18342897
# 2004-08-24  55.412300  55.591629  51.591621  52.239197  52.239197  15319808
# 2004-08-25  52.284027  53.798351  51.746044  52.802086  52.802086   9232276
#
#              month        day
# Date
# 2004-08-19  August   Thursday
# 2004-08-20  August     Friday
# 2004-08-23  August     Monday
# 2004-08-24  August    Tuesday
# 2004-08-25  August  Wednesday

# %%
google['quarter'] = google.index.quarter

# %%
google.loc['2021-5-12':'2021-7-15']
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2021-05-12  2261.709961  2285.370117  2230.050049  2239.080078  2239.080078
# 2021-05-13  2261.090088  2276.601074  2242.719971  2261.969971  2261.969971
# 2021-05-14  2291.830078  2321.139893  2283.320068  2316.159912  2316.159912
# 2021-05-17  2309.320068  2323.340088  2295.000000  2321.409912  2321.409912
# 2021-05-18  2336.906006  2343.149902  2303.159912  2303.429932  2303.429932
# 2021-05-19  2264.399902  2316.760010  2263.520020  2308.709961  2308.709961
# 2021-05-20  2328.040039  2360.340088  2321.090088  2356.090088  2356.090088
# 2021-05-21  2365.989990  2369.000000  2342.370117  2345.100098  2345.100098
# 2021-05-24  2367.000000  2418.479980  2360.110107  2406.669922  2406.669922
# 2021-05-25  2420.000000  2432.889893  2402.989990  2409.070068  2409.070068
# 2021-05-26  2412.834961  2442.944092  2412.514893  2433.530029  2433.530029
# ...

# %%
# fetch the info for a particular date every year  -> limitation of tiledelta
pd.date_range(start = '2005-1-6',end = '2022-1-6',freq=pd.DateOffset(years=1))
# Out:
# DatetimeIndex(['2005-01-06', '2006-01-06', '2007-01-06', '2008-01-06',
#                '2009-01-06', '2010-01-06', '2011-01-06', '2012-01-06',
#                '2013-01-06', '2014-01-06', '2015-01-06', '2016-01-06',
#                '2017-01-06', '2018-01-06', '2019-01-06', '2020-01-06',
#                '2021-01-06', '2022-01-06'],
#               dtype='datetime64[ns]', freq='<DateOffset: years=1>')

# %%
google[google.index.isin(pd.date_range(start = '2005-1-6',end = '2022-1-6',freq=pd.DateOffset(years=1)))]
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2005-01-06    97.175758    97.584229    93.509506    93.922951    93.922951
# 2006-01-06   227.581970   234.371521   225.773743   231.960556   231.960556
# 2009-01-06   165.868286   169.763687   162.585587   166.406265   166.406265
# 2010-01-06   311.761444   311.761444   302.047852   302.994293   302.994293
# 2011-01-06   304.199799   308.060303   303.885956   305.604523   305.604523
# 2012-01-06   328.344299   328.767700   323.681763   323.796326   323.796326
# 2014-01-06   554.426880   557.340942   551.154114   556.573853   556.573853
# 2015-01-06   513.589966   514.761719   499.678131   500.585632   500.585632
# 2016-01-06   730.000000   747.179993   728.919983   743.619995   743.619995
# 2017-01-06   795.260010   807.900024   792.203979   806.150024   806.150024
# 2020-01-06  1350.000000  1396.500000  1350.000000  1394.209961  1394.209961
# ...

# %%
google['Close'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
google.loc['2021']['Close'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
# frequency
google.index
# Out:
# DatetimeIndex(['2004-08-19', '2004-08-20', '2004-08-23', '2004-08-24',
#                '2004-08-25', '2004-08-26', '2004-08-27', '2004-08-30',
#                '2004-08-31', '2004-09-01',
#                ...
#                '2022-05-09', '2022-05-10', '2022-05-11', '2022-05-12',
#                '2022-05-13', '2022-05-16', '2022-05-17', '2022-05-18',
#                '2022-05-19', '2022-05-20'],
#               dtype='datetime64[ns]', name='Date', length=4471, freq=None)

# %%
 # asfreq
 google.asfreq('D')
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2004-08-19    49.813290    51.835709    47.800831    49.982655    49.982655
# 2004-08-20    50.316402    54.336334    50.062355    53.952770    53.952770
# 2004-08-21          NaN          NaN          NaN          NaN          NaN
# 2004-08-22          NaN          NaN          NaN          NaN          NaN
# 2004-08-23    55.168217    56.528118    54.321388    54.495735    54.495735
# ...                 ...          ...          ...          ...          ...
# 2022-05-16  2307.679932  2332.149902  2286.699951  2295.850098  2295.850098
# 2022-05-17  2344.550049  2344.550049  2306.750000  2334.030029  2334.030029
# 2022-05-18  2304.750000  2313.913086  2242.840088  2248.020020  2248.020020
# 2022-05-19  2236.820068  2271.750000  2209.360107  2214.909912  2214.909912
# 2022-05-20  2241.709961  2251.000000  2127.459961  2186.260010  2186.260010
#
# ...

# %%
 # asfreq
 google = google.asfreq('B')

# %%
google.index
# Out:
# DatetimeIndex(['2004-08-19', '2004-08-20', '2004-08-23', '2004-08-24',
#                '2004-08-25', '2004-08-26', '2004-08-27', '2004-08-30',
#                '2004-08-31', '2004-09-01',
#                ...
#                '2022-05-09', '2022-05-10', '2022-05-11', '2022-05-12',
#                '2022-05-13', '2022-05-16', '2022-05-17', '2022-05-18',
#                '2022-05-19', '2022-05-20'],
#               dtype='datetime64[ns]', name='Date', length=4632, freq='B')

# %%
 # asfreq
 google.asfreq('Q')
# Out:
# <ipython-input-47-abcbf53d6717>:2: FutureWarning: 'Q' is deprecated and will be removed in a future version, please use 'QE' instead.
#   google.asfreq('Q')
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2004-09-30    64.707458    65.902977    64.259140    64.558022    64.558022
# 2004-12-31    99.243011    99.566795    95.920464    96.035034    96.035034
# 2005-03-31    88.642746    90.356323    88.488327    89.917969    89.917969
# 2005-06-30   146.620438   148.906860   144.976593   146.525787   146.525787
# 2005-09-30   156.523315   158.157181   155.561920   157.639130   157.639130
# ...                 ...          ...          ...          ...          ...
# 2021-03-31  2059.120117  2093.326904  2056.745117  2068.629883  2068.629883
# 2021-06-30  2513.071045  2516.000000  2495.149902  2506.320068  2506.320068
# 2021-09-30  2686.500000  2711.800049  2660.000000  2665.310059  2665.310059
# ...

# %%
 # asfreq
 google.asfreq('Y')
# Out:
# <ipython-input-48-772008a56053>:2: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   google.asfreq('Y')
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2004-12-31    99.243011    99.566795    95.920464    96.035034    96.035034
# 2005-12-31          NaN          NaN          NaN          NaN          NaN
# 2006-12-31          NaN          NaN          NaN          NaN          NaN
# 2007-12-31   347.980682   349.933350   344.000610   344.448914   344.448914
# 2008-12-31   151.532028   154.919327   150.739990   153.250580   153.250580
# 2009-12-31   311.208527   311.532288   308.832428   308.832428   308.832428
# 2010-12-31   297.255798   298.092682   294.909607   295.875977   295.875977
# 2011-12-31          NaN          NaN          NaN          NaN          NaN
# 2012-12-31   348.693024   353.958282   346.700470   352.369232   352.369232
# ...

# %%
 # asfreq
 google.asfreq('M')
# Out:
# <ipython-input-49-fefe61765547>:2: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   google.asfreq('M')
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2004-08-31    50.958992    51.661362    50.889256    50.993862    50.993862
# 2004-09-30    64.707458    65.902977    64.259140    64.558022    64.558022
# 2004-10-31          NaN          NaN          NaN          NaN          NaN
# 2004-11-30    90.017593    91.158318    89.788452    90.650223    90.650223
# 2004-12-31    99.243011    99.566795    95.920464    96.035034    96.035034
# ...                 ...          ...          ...          ...          ...
# 2021-12-31  2910.879883  2927.300049  2893.550049  2893.590088  2893.590088
# 2022-01-31  2683.959961  2716.870117  2645.479980  2713.969971  2713.969971
# 2022-02-28  2665.689941  2712.810059  2656.504883  2697.820068  2697.820068
# ...

# %%
 # asfreq
 google.asfreq('6H',method = 'bfill')
# Out:
# <ipython-input-50-8ffabf5dfd0f>:2: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   google.asfreq('6H',method = 'bfill')
#                             Open         High          Low        Close  \
# Date
# 2004-08-19 00:00:00    49.813290    51.835709    47.800831    49.982655
# 2004-08-19 06:00:00    50.316402    54.336334    50.062355    53.952770
# 2004-08-19 12:00:00    50.316402    54.336334    50.062355    53.952770
# 2004-08-19 18:00:00    50.316402    54.336334    50.062355    53.952770
# 2004-08-20 00:00:00    50.316402    54.336334    50.062355    53.952770
# ...                          ...          ...          ...          ...
# 2022-05-19 00:00:00  2236.820068  2271.750000  2209.360107  2214.909912
# 2022-05-19 06:00:00  2241.709961  2251.000000  2127.459961  2186.260010
# 2022-05-19 12:00:00  2241.709961  2251.000000  2127.459961  2186.260010
# 2022-05-19 18:00:00  2241.709961  2251.000000  2127.459961  2186.260010
# ...

# %%
 # asfreq
 google.asfreq('6H',method = 'ffill')
# Out:
# <ipython-input-51-3a64622f0e1a>:2: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   google.asfreq('6H',method = 'ffill')
#                             Open         High          Low        Close  \
# Date
# 2004-08-19 00:00:00    49.813290    51.835709    47.800831    49.982655
# 2004-08-19 06:00:00    49.813290    51.835709    47.800831    49.982655
# 2004-08-19 12:00:00    49.813290    51.835709    47.800831    49.982655
# 2004-08-19 18:00:00    49.813290    51.835709    47.800831    49.982655
# 2004-08-20 00:00:00    50.316402    54.336334    50.062355    53.952770
# ...                          ...          ...          ...          ...
# 2022-05-19 00:00:00  2236.820068  2271.750000  2209.360107  2214.909912
# 2022-05-19 06:00:00  2236.820068  2271.750000  2209.360107  2214.909912
# 2022-05-19 12:00:00  2236.820068  2271.750000  2209.360107  2214.909912
# 2022-05-19 18:00:00  2236.820068  2271.750000  2209.360107  2214.909912
# ...

# %%
# quaterly trend
google.asfreq('Q').plot()
# Out:
# <ipython-input-52-72f171963f46>:2: FutureWarning: 'Q' is deprecated and will be removed in a future version, please use 'QE' instead.
#   google.asfreq('Q').plot()
# <Axes: xlabel='Date'>

# %%
# resampling
# downsampling
google['Close'].resample('M').mean().plot()
# Out:
# <ipython-input-64-3a78af7139e1>:3: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   google['Close'].resample('M').mean().plot()
# <Axes: xlabel='Date'>

# %%
google['Close'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
# upsampling
google['Close'].resample('H').interpolate(method='linear')
# Out:
# <ipython-input-66-c768339065e1>:2: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   google['Close'].resample('H').interpolate(method='linear')
# Date
# 2004-08-19 00:00:00      49.982655
# 2004-08-19 01:00:00      50.148076
# 2004-08-19 02:00:00      50.313498
# 2004-08-19 03:00:00      50.478919
# 2004-08-19 04:00:00      50.644341
#                           ...
# 2022-05-19 20:00:00    2191.034994
# 2022-05-19 21:00:00    2189.841248
# 2022-05-19 22:00:00    2188.647502
# 2022-05-19 23:00:00    2187.453756
# 2022-05-20 00:00:00    2186.260010
# Freq: h, Name: Close, Length: 155593, dtype: float64

# %%
# upsampling
google['Close'].resample('H').interpolate(method='spline',order =2)
# Out:
# <ipython-input-67-b3171448742b>:2: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   google['Close'].resample('H').interpolate(method='spline',order =2)
# Date
# 2004-08-19 00:00:00      49.982655
# 2004-08-19 01:00:00      50.054174
# 2004-08-19 02:00:00      50.278766
# 2004-08-19 03:00:00      50.499453
# 2004-08-19 04:00:00      50.716235
#                           ...
# 2022-05-19 20:00:00    2116.145684
# 2022-05-19 21:00:00    2130.864097
# 2022-05-19 22:00:00    2147.454745
# 2022-05-19 23:00:00    2165.917626
# 2022-05-20 00:00:00    2186.260010
# Freq: h, Name: Close, Length: 155593, dtype: float64

# %%
# rolling window
google['Close'].rolling(3).mean()
# Out:
# Date
# 2004-08-19            NaN
# 2004-08-20            NaN
# 2004-08-23      52.810387
# 2004-08-24      53.562567
# 2004-08-25      53.179006
#                  ...
# 2022-05-16    2296.460043
# 2022-05-17    2320.063395
# 2022-05-18    2292.633382
# 2022-05-19    2265.653320
# 2022-05-20    2216.396647
# Freq: B, Name: Close, Length: 4632, dtype: float64

# %%
# shifting
google['Close']
# Out:
# Date
# 2004-08-19      49.982655
# 2004-08-20      53.952770
# 2004-08-23      54.495735
# 2004-08-24      52.239197
# 2004-08-25      52.802086
#                  ...
# 2022-05-16    2295.850098
# 2022-05-17    2334.030029
# 2022-05-18    2248.020020
# 2022-05-19    2214.909912
# 2022-05-20    2186.260010
# Freq: B, Name: Close, Length: 4632, dtype: float64

# %%
google['Close'].shift(1)
# Out:
# Date
# 2004-08-19            NaN
# 2004-08-20      49.982655
# 2004-08-23      53.952770
# 2004-08-24      54.495735
# 2004-08-25      52.239197
#                  ...
# 2022-05-16    2330.310059
# 2022-05-17    2295.850098
# 2022-05-18    2334.030029
# 2022-05-19    2248.020020
# 2022-05-20    2214.909912
# Freq: B, Name: Close, Length: 4632, dtype: float64

# %%
login = pd.read_csv('/content/login.csv',header=None)

# %%
login.head()
# Out:
#    0    1                    2           3
# 0  1  466  2017-01-07 18:24:07  Unnamed: 3
# 1  2  466  2017-01-07 18:24:55         NaN
# 2  3  458  2017-01-07 18:25:18         NaN
# 3  4  458  2017-01-07 18:26:21         NaN
# 4  5  592  2017-01-07 19:09:59         NaN

# %%
df = login[[1,2]]

# %%
df.head()
# Out:
#      1                    2
# 0  466  2017-01-07 18:24:07
# 1  466  2017-01-07 18:24:55
# 2  458  2017-01-07 18:25:18
# 3  458  2017-01-07 18:26:21
# 4  592  2017-01-07 19:09:59

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3003 entries, 0 to 3002
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   1       3003 non-null   int64
#  1   2       3003 non-null   object
# dtypes: int64(1), object(1)
# memory usage: 47.1+ KB

# %%
df.rename(columns = {1:'uid',2:'login_time'},inplace = True)
# Out:
# <ipython-input-92-797f8972fc38>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns = {1:'uid',2:'login_time'},inplace = True)

# %%
df
# Out:
#        uid           login_time
# 0      466  2017-01-07 18:24:07
# 1      466  2017-01-07 18:24:55
# 2      458  2017-01-07 18:25:18
# 3      458  2017-01-07 18:26:21
# 4      592  2017-01-07 19:09:59
# ...    ...                  ...
# 2998  1307  2018-01-04 10:48:28
# 2999  1230  2018-01-04 11:22:00
# 3000  1307  2018-01-04 13:13:44
# 3001  1307  2018-01-04 13:13:45
# 3002  1224  2018-01-04 14:10:04
#
# [3003 rows x 2 columns]

# %%
df['uid'].value_counts()
# Out:
# uid
# 413     222
# 458     208
# 492     162
# 882     140
# 592     122
#        ...
# 1275      1
# 1276      1
# 639       1
# 1279      1
# 636       1
# Name: count, Length: 433, dtype: int64

# %%
user_df = df[df['uid'] == 413]

# %%
user_df.head()
# Out:
#     uid           login_time
# 11  413  2017-01-09 12:29:25
# 12  413  2017-01-09 12:40:39
# 14  413  2017-01-09 14:08:04
# 33  413  2017-01-10 14:36:23
# 35  413  2017-01-10 15:22:45

# %%
user_df['login_time'] = pd.to_datetime(df['login_time'])
# Out:
# <ipython-input-99-1f2f92896a35>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_df['login_time'] = pd.to_datetime(df['login_time'])

# %%
user_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 222 entries, 11 to 2997
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   uid         222 non-null    int64
#  1   login_time  222 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 13.3 KB

# %%
user_df['shifted']=user_df['login_time'].shift(1)
# Out:
# <ipython-input-105-d01132d6308c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_df['shifted']=user_df['login_time'].shift(1)

# %%
user_df
# Out:
#       uid          login_time              shfted             shifted
# 11    413 2017-01-09 12:29:25                 NaT                 NaT
# 12    413 2017-01-09 12:40:39 2017-01-09 12:29:25 2017-01-09 12:29:25
# 14    413 2017-01-09 14:08:04 2017-01-09 12:40:39 2017-01-09 12:40:39
# 33    413 2017-01-10 14:36:23 2017-01-09 14:08:04 2017-01-09 14:08:04
# 35    413 2017-01-10 15:22:45 2017-01-10 14:36:23 2017-01-10 14:36:23
# ...   ...                 ...                 ...                 ...
# 2958  413 2017-12-29 18:20:32 2017-12-29 18:19:48 2017-12-29 18:19:48
# 2963  413 2017-12-30 13:41:21 2017-12-29 18:20:32 2017-12-29 18:20:32
# 2974  413 2018-01-01 15:16:25 2017-12-30 13:41:21 2017-12-30 13:41:21
# 2982  413 2018-01-02 18:15:45 2018-01-01 15:16:25 2018-01-01 15:16:25
# 2997  413 2018-01-04 10:43:43 2018-01-02 18:15:45 2018-01-02 18:15:45
#
# [222 rows x 4 columns]

# %%
(user_df['login_time'] - user_df['shifted']).mean()
# Out:
# Timedelta('1 days 15:05:13.384615384')
