# %% [markdown]
# <a href="https://colab.research.google.com/github/Swapn2/Data-Science-Learnings/blob/main/pandas_case_study_textual.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/content/IMDB Dataset.csv')

# %%
df
# Out:
#                                                   review sentiment
# 0      One of the other reviewers has mentioned that ...  positive
# 1      A wonderful little production. <br /><br />The...  positive
# 2      I thought this was a wonderful way to spend ti...  positive
# 3      Basically there's a family where a little boy ...  negative
# 4      Petter Mattei's "Love in the Time of Money" is...  positive
# ...                                                  ...       ...
# 49995  I thought this movie did a down right good job...  positive
# 49996  Bad plot, bad dialogue, bad acting, idiotic di...  negative
# 49997  I am a Catholic taught in parochial elementary...  negative
# 49998  I'm going to have to disagree with the previou...  negative
# 49999  No one expects the Star Trek movies to be high...  negative
#
# [50000 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   review     50000 non-null  object
#  1   sentiment  50000 non-null  object
# dtypes: object(2)
# memory usage: 781.4+ KB

# %%
df.duplicated().sum()
# Out:
# np.int64(418)

# %%
df = df.drop_duplicates()

# %%
df = df.iloc[:20000]

# %%
# lowercase
df['review'] = df['review'].str.lower()

# %%
# removing leading and trailing spaces
df['review'] = df['review'].str.strip()

# %%
# removing HTML tags
# we will use regx for this
# remove html tags

import re
def remove_html(data):
    data=re.sub(r'<.*?>','',data)
    return data

# %%
df['review'].apply(remove_html)
# Out:
# 0        one of the other reviewers has mentioned that ...
# 1        a wonderful little production. the filming tec...
# 2        i thought this was a wonderful way to spend ti...
# 3        basically there's a family where a little boy ...
# 4        petter mattei's "love in the time of money" is...
#                                ...
# 20070    my take: a goofy, yet imaginative mess. keanu ...
# 20071    this is at least very close to a perfect video...
# 20072    man on fire was hot. i love a classic tale of ...
# 20073    thankfully brief mystery about a telephone ope...
# 20074    don't pick this one. ****spoiler alert***** th...
# Name: review, Length: 20000, dtype: object

# %%
# method 2
df['review'].str.replace(r'<.*?>','',regex = True)
# Out:
# 0        one of the other reviewers has mentioned that ...
# 1        a wonderful little production. the filming tec...
# 2        i thought this was a wonderful way to spend ti...
# 3        basically there's a family where a little boy ...
# 4        petter mattei's "love in the time of money" is...
#                                ...
# 20070    my take: a goofy, yet imaginative mess. keanu ...
# 20071    this is at least very close to a perfect video...
# 20072    man on fire was hot. i love a classic tale of ...
# 20073    thankfully brief mystery about a telephone ope...
# 20074    don't pick this one. ****spoiler alert***** th...
# Name: review, Length: 20000, dtype: object

# %%
df.head()
# Out:
#                                               review sentiment
# 0  one of the other reviewers has mentioned that ...  positive
# 1  a wonderful little production. <br /><br />the...  positive
# 2  i thought this was a wonderful way to spend ti...  positive
# 3  basically there's a family where a little boy ...  negative
# 4  petter mattei's "love in the time of money" is...  positive
